# %%
#seaborn has dependencies-Pandas,numpy,matplotlib, and statsmodels
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#importing file with two methods
df=pd.read_csv("C:/Users/User/Downloads/Chicago_Crime_Detective.csv",encoding='unicode_escape',index_col=0)
#df=pd.read_csv("C:\\Users\\User\\Downloads\\Chicago_Crime_Detective.csv",index_col=0)     this can be done as well
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#         ID            Date            LocationDescription  Arrest  Domestic  \
# 0  8951354  12/31/12 23:15                         STREET   False     False
# 1  8951141  12/31/12 22:00                         STREET   False     False
# 2  8952745  12/31/12 22:00  RESIDENTIAL YARD (FRONT/BACK)   False     False
# 3  8952223  12/31/12 22:00                         STREET   False     False
# 4  8951608  12/31/12 21:30                         STREET   False     False
#
#    Beat District CommunityArea  Year
# 0   623        6            69  2012
# 1  1213       12            24  2012
# 2  1622       16            11  2012
# 3   724        7            67  2012
# 4   211        2            35  2012

# %%
#to change the datetime format yyyy-mm-dd hh:mm:ss
df['Date']=pd.to_datetime(df['Date'])

# %%
df.head()
# Out:
#         ID                Date            LocationDescription  Arrest  \
# 0  8951354 2012-12-31 23:15:00                         STREET   False
# 1  8951141 2012-12-31 22:00:00                         STREET   False
# 2  8952745 2012-12-31 22:00:00  RESIDENTIAL YARD (FRONT/BACK)   False
# 3  8952223 2012-12-31 22:00:00                         STREET   False
# 4  8951608 2012-12-31 21:30:00                         STREET   False
#
#    Domestic  Beat District CommunityArea  Year
# 0     False   623        6            69  2012
# 1     False  1213       12            24  2012
# 2     False  1622       16            11  2012
# 3     False   724        7            67  2012
# 4     False   211        2            35  2012

# %%
df['Date']=df['Date'].sort_values()

# %%
df['Date']=df['Date'].sort_values()      #median date
df.Date[(len(df.Date)+1)/2]
# Out:
# Timestamp('2006-05-21 12:00:00')

# %%
df["Date"]=df['Date'].sort_values()

# %%
df.head()
# Out:
#         ID                Date            LocationDescription  Arrest  \
# 0  8951354 2012-12-31 23:15:00                         STREET   False
# 1  8951141 2012-12-31 22:00:00                         STREET   False
# 2  8952745 2012-12-31 22:00:00  RESIDENTIAL YARD (FRONT/BACK)   False
# 3  8952223 2012-12-31 22:00:00                         STREET   False
# 4  8951608 2012-12-31 21:30:00                         STREET   False
#
#    Domestic  Beat District CommunityArea  Year
# 0     False   623        6            69  2012
# 1     False  1213       12            24  2012
# 2     False  1622       16            11  2012
# 3     False   724        7            67  2012
# 4     False   211        2            35  2012

# %%
df['Date']=df['Date'].sort_values()
df.groupby('Date').quantile(.5)      #median method(not sure)
# Out:
# 0.5                         ID  Arrest  Domestic    Beat    Year  month
# Date
# 2001-01-01 00:01:00  1313423.0     0.0       0.0  1811.5  2001.0    1.0
# 2001-01-01 00:05:00  1310755.0     0.0       0.0  2332.0  2001.0    1.0
# 2001-01-01 00:30:00  1314405.0     0.0       0.0  1268.0  2001.0    1.0
# 2001-01-01 01:17:00  1310583.0     0.0       0.0   433.0  2001.0    1.0
# 2001-01-01 01:50:00  1310022.0     1.0       0.0  2233.0  2001.0    1.0
# 2001-01-01 02:00:00  1310685.0     0.0       0.0  1513.0  2001.0    1.0
# 2001-01-01 03:00:00  1310771.5     0.5       0.0  1273.0  2001.0    1.0
# 2001-01-01 03:57:00  1918550.0     0.0       0.0  1434.0  2001.0    1.0
# 2001-01-01 04:00:00  1313456.0     0.0       0.0   911.0  2001.0    1.0
# 2001-01-01 04:30:00  1918518.0     0.0       0.0  2522.0  2001.0    1.0
# 2001-01-01 05:00:00  1311605.5     0.0       0.0  1473.5  2001.0    1.0
# 2001-01-01 08:00:00  1850130.0     0.0       0.0  2233.0  2001.0    1.0
# ...

# %%
df['month']=df['Date'].dt.month
df['month'].value_counts()           #first making a sperarate column & then grouping according to month
# Out:
# 10    17086
# 7     16801
# 8     16572
# 12    16426
# 11    16063
# 9     16060
# 1     16047
# 5     16035
# 6     16002
# 3     15758
# 4     15280
# 2     13511
# Name: month, dtype: int64

# %%
df.Date.dt.weekday.value_counts()       #grouping according to weekdays
# Out:
# 4    29284
# 2    27416
# 0    27397
# 3    27319
# 5    27118
# 1    26791
# 6    26316
# Name: Date, dtype: int64

# %%
df.groupby(['month','Arrest'])['ID'].count()    #grouping according to month separating when arrests were made or when not
# Out:
# month  Arrest
# 1      False     14612
#        True       1435
# 2      False     12273
#        True       1238
# 3      False     14460
#        True       1298
# 4      False     14028
#        True       1252
# 5      False     14848
#        True       1187
# 6      False     14772
#        True       1230
# 7      False     15477
#        True       1324
# 8      False     15243
#        True       1329
# 9      False     14812
#        True       1248
# 10     False     15744
#        True       1342
# 11     False     14807
#        True       1256
# 12     False     15029
#        True       1397
# Name: ID, dtype: int64

# %%
df1=df.groupby('Year')['ID'].count()
df1                             #grouping according to year column
# Out:
# Year
# 2001    20669
# 2002    18753
# 2003    16657
# 2004    16862
# 2005    16484
# 2006    16098
# 2007    14280
# 2008    14445
# 2009    12167
# 2010    15497
# 2011    15637
# 2012    14092
# Name: ID, dtype: int64

# %%
df.groupby(['Year','Arrest'])['ID'].count()
# Out:
# Year  Arrest
# 2001  False     18517
#       True       2152
# 2002  False     16638
#       True       2115
# 2003  False     14859
#       True       1798
# 2004  False     15169
#       True       1693
# 2005  False     14956
#       True       1528
# 2006  False     14796
#       True       1302
# 2007  False     13068
#       True       1212
# 2008  False     13425
#       True       1020
# 2009  False     11327
#       True        840
# 2010  False     14796
#       True        701
# 2011  False     15012
#       True        625
# 2012  False     13542
#       True        550
# Name: ID, dtype: int64

# %%
2152/20669
# Out:
# 0.10411727708161982

# %%
(1212/14280)
#(2152+2115+1798+1693+1528+1302)
#(1020+840+701+625+550)
# Out:
# 0.08487394957983194

# %%
df.groupby('LocationDescription')['ID'].count().sort_values(ascending=False)
# Out:
# LocationDescription
# STREET                                             156564
# PARKING LOT/GARAGE(NON.RESID.)                      14852
# OTHER                                                4573
# ALLEY                                                2308
# GAS STATION                                          2111
# DRIVEWAY - RESIDENTIAL                               1675
# RESIDENTIAL YARD (FRONT/BACK)                        1536
# RESIDENCE                                            1302
# RESIDENCE-GARAGE                                     1176
# VACANT LOT/LAND                                       985
# VEHICLE NON-COMMERCIAL                                817
# SIDEWALK                                              462
# CHA PARKING LOT/GROUNDS                               405
# AIRPORT/AIRCRAFT                                      363
# POLICE FACILITY/VEH PARKING LOT                       266
# PARK PROPERTY                                         255
# ...

# %%
156564+14852+2308+2111+1675
# Out:
# 177510

# %%
df2=df[df['LocationDescription']=='GAS STATION']      #df subset where location=Gas station
df2.groupby('weekday')["ID"].count()
# Out:
# weekday
# 0    280
# 1    270
# 2    273
# 3    282
# 4    332
# 5    338
# 6    336
# Name: ID, dtype: int64
